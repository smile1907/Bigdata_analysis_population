# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
font_dirs = ['/usr/share/fonts/truetype/nanum', ]
font_files = fm.findSystemFonts(fontpaths=font_dirs)
for font_file in font_files:
    fm.fontManager.addfont(font_file)

# %%
plt.rcParams['font.family'] = 'NanumBarunGothic'
plt.rcParams['axes.unicode_minus']=False

# %%
a = pd.read_csv('C:/Users/ysb/Desktop/전공공부 외/스터디/전출인구_시도_시_군_구.csv', encoding="euc-kr")
a.head()
# Out:
#   행정구역(시군구)별(1) 행정구역(시군구)별(2) 2019. 01 2019. 02 2019. 03 2019. 04 2019. 05  \
# 0            전국            소계  667,227  702,329  641,449  587,293  569,020
# 1         서울특별시            소계  129,031  143,367  137,242  122,867  117,209
# 2         서울특별시           종로구    2,068    2,524    2,414    1,939    1,979
# 3         서울특별시            중구    1,534    1,839    1,729    1,524    1,548
# 4         서울특별시           용산구    3,006    3,272    3,155    2,973    3,014
#
#   2019. 06 2019. 07 2019. 08  ... 2020. 09 2020. 10 2020. 11 2020. 12  \
# 0  484,468  563,622  565,607  ...  621,468  604,412  610,204  717,622
# 1   97,933  118,365  118,002  ...  137,952  137,100  127,049  144,245
# 2    1,640    1,880    1,924  ...    2,058    1,988    1,883    1,984
# 3    1,366    1,616    1,786  ...    2,011    1,681    1,701    1,914
# 4    2,517    2,863    2,787  ...    3,435    3,363    3,006    3,483
#
#   2021. 01 2021. 02 2021. 03 2021. 04 2021. 05 2021. 06
# ...

# %%
a.info()
a['2019. 01'].str.replace(',','').astype(int)
a['2019. 02'].str.replace(',','').astype(int)
a['2019. 03'].str.replace(',','').astype(int)
a['2019. 04'].str.replace(',','').astype(int)
a['2019. 05'].str.replace(',','').astype(int)
a['2019. 06'].str.replace(',','').astype(int)
a['2019. 07'].str.replace(',','').astype(int)
a['2019. 08'].str.replace(',','').astype(int)
a['2019. 09'].str.replace(',','').astype(int)
a['2019. 10'].str.replace(',','').astype(int)
a['2019. 11'].str.replace(',','').astype(int)
a['2019. 12'].str.replace(',','').astype(int)
a['2020. 01'].str.replace(',','').astype(int)
a['2020. 02'].str.replace(',','').astype(int)
a['2020. 03'].str.replace(',','').astype(int)
a['2020. 04'].str.replace(',','').astype(int)
a['2020. 05'].str.replace(',','').astype(int)
a['2020. 06'].str.replace(',','').astype(int)
a['2020. 07'].str.replace(',','').astype(int)
a['2020. 08'].str.replace(',','').astype(int)
a['2020. 09'].str.replace(',','').astype(int)
a['2020. 10'].str.replace(',','').astype(int)
a['2020. 11'].str.replace(',','').astype(int)
a['2020. 12'].str.replace(',','').astype(int)
a['2021. 01'].str.replace(',','').astype(int)
a['2021. 02'].str.replace(',','').astype(int)
a['2021. 03'].str.replace(',','').astype(int)
a['2021. 04'].str.replace(',','').astype(int)
a['2021. 05'].str.replace(',','').astype(int)
a['2021. 06'].str.replace(',','').astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   행정구역(시군구)별(1)  266 non-null    object
#  1   행정구역(시군구)별(2)  266 non-null    object
#  2   2019. 01       266 non-null    object
#  3   2019. 02       266 non-null    object
#  4   2019. 03       266 non-null    object
#  5   2019. 04       266 non-null    object
#  6   2019. 05       266 non-null    object
#  7   2019. 06       266 non-null    object
#  8   2019. 07       266 non-null    object
#  9   2019. 08       266 non-null    object
#  10  2019. 09       266 non-null    object
#  11  2019. 10       266 non-null    object
#  12  2019. 11       266 non-null    object
#  13  2019. 12       266 non-null    object
#  14  2020. 01       266 non-null    object
#  15  2020. 02       266 non-null    object
#  16  2020. 03       266 non-null    object
# ...

# %%
a_경상남도 = a[a['행정구역(시군구)별(1)'] == '경상남도']
a_경상남도
# Out:
#     행정구역(시군구)별(1) 행정구역(시군구)별(2) 2019. 01 2019. 02 2019. 03 2019. 04 2019. 05  \
# 242          경상남도            소계   40,989   43,422   37,827   33,844   31,921
# 243          경상남도           창원시   13,839   13,480   11,654   10,093    9,273
# 244          경상남도           진주시    5,073    5,862    4,652    3,800    3,671
# 245          경상남도           통영시    1,923    1,936    1,571    1,449    1,495
# 246          경상남도           사천시    1,538    1,784    1,455    1,245    1,209
# 247          경상남도           김해시    5,849    6,932    6,890    6,949    5,873
# 248          경상남도           밀양시    1,194    1,087    1,046    1,026    1,239
# 249          경상남도           거제시    3,348    3,662    3,060    2,519    2,625
# 250          경상남도           양산시    3,487    3,857    3,230    3,078    3,076
# 251          경상남도           의령군      295      239      242      207      177
# 252          경상남도           함안군      703      788      641      572      538
# ...

# %%
import matplotlib.font_manager as fm

font_dirs = [r'C:\Users\Administrator\AppData\Local\Microsoft\Windows\Fonts' ]
font_files = fm.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    fm.fontManager.addfont(font_file)

# %%
b = a_경상남도.iloc[:,2:32] 
#b.mean(axis=1)
c1 = b['2019. 01'].str.replace(',','').astype(int)
plt.figure(figsize=(20,10))
plt.rc('font', family="NanumBarunGothic")
plt.rcParams['axes.unicode_minus'] = False
plt.xticks()

c1.plot()
# Out:
# <AxesSubplot:>

# %%
c2 = a_경상남도.iloc[:,1:2]
c = pd.concat([c2,c1],axis=1) 
c = c.set_index("행정구역(시군구)별(2)")
c.index
c.plot(kind=('bar'))
# Out:
# <AxesSubplot:xlabel='행정구역(시군구)별(2)'>
# C:\Users\ysb\anaconda3\envs\mlcc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52285 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ysb\anaconda3\envs\mlcc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ysb\anaconda3\envs\mlcc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ysb\anaconda3\envs\mlcc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ysb\anaconda3\envs\mlcc\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 53685 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
